# %% [markdown]
# <a href="https://colab.research.google.com/github/Gilf641/EVA4/blob/master/S13/S13_YoloV3(MetalCanDetector).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Motivation**:
#  Waste Segregator Robo which seperates Recyclable & Non-Recyclable Waste Materials and dumps them into resp bins.
#
# **Number of Classes**: 1
#
# **[*Plastic*]**

# %% [markdown]
# # ***Steps to Follow:***

# %% [markdown]
# **1. Clone the Github Repo**

# %%
# !git clone https://github.com/Gilf641/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 2773, done.
# remote: Counting objects: 100% (2773/2773), done.
# remote: Compressing objects: 100% (2540/2540), done.
# remote: Total 3247 (delta 23), reused 2761 (delta 14), pack-reused 474
# Receiving objects: 100% (3247/3247), 31.83 MiB | 41.62 MiB/s, done.
# Resolving deltas: 100% (102/102), done.

# %% [markdown]
# **2. Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **3. Display Framework & Device Properties**

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %% [markdown]
# **4. Change current working directory to YoloV3/**

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png

# %% [markdown]
# **5. Add Weights Folder and paste YoloV3 Weights**

# %%
! mkdir weights 
# !cd weights/
! wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-07-04 03:57:53--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights        1%[                    ]   3.60M  1.10MB/s    eta 3m 40s ^C

# %% [markdown]
# **6. Train YoloV3 on smalcoco**

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 1 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=1, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-07-04 04:02:21.957869: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# ...

# %% [markdown]
# **7. Train YoloV3 on Custom Dataset(WasteMaterials in my case)**

# %%
# !python train.py --data data/customdata/custom.data --batch 12 --cache --cfg cfg/yolov3-custom.cfg --epochs 70 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=12, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=70, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-07-04 04:27:19.394015: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **8. Test the model & Save all the results in out_out/**

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# ...

# %%
# !mkdir prevWeights
# !cd prevWeights
# !cp -R "/content/gdrive/My Drive/CV/weights/" "/content/YoloV3/prevWeights/"  
# !python detect.py --conf-thres 0.1 --weights /content/YoloV3/prevWeights/weights/last.pt --output out_out
# Out:
# mkdir: cannot create directory ‘prevWeights’: File exists
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='/content/YoloV3/prevWeights/weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out --fourcc out_out/
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='out_out/', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# ...

# %% [markdown]
# # ***Test Results***

# %%
Image(filename='out_out/metal20.jpg', width=600)

# %%
Image(filename='out_out/cardboard068.jpg', width=600)

# %%
Image(filename='out_out/metal12.jpg', width=600)

# %%
Image(filename='out_out/metal48.jpg', width=600)

# %%
Image(filename='out_out/metalcan013.jpg', width=600)

# %%
Image(filename='out_out/paper018.jpg', width=600)

# %%
Image(filename='out_out/paper073.jpg', width=600)

# %%
Image(filename='out_out/paper002.jpg', width=600)

# %%
Image(filename='out_out/paper029.jpg', width=600)

# %%
! cd YoloV3/
# !ls
# Out:
# /bin/bash: line 0: cd: YoloV3/: No such file or directory
#  annotation_tool   out_out	  results.txt	     train.py
#  cfg		   output	  runs		    'ubdivisions=1'
#  data		   __pycache__	  test_batch0.png    utils
#  detect.py	   README.md	  test.py	     vim.exe.stackdump
#  last.pt	   results.json   ting		     weights
#  models.py	   results.png	  train_batch0.png

# %% [markdown]
# **Use this command to move model**

# %%
# !mv "/content/YoloV3/last.pt" "/content/YoloV3/weights/"

# %%
# !cp -R "/content/YoloV3/weights/"  "/content/gdrive/My Drive/YoloWeights/"

# %%
# !mv "/content/YoloV3/weights/last.pt" "/content/gdrive/My Drive//"
# Out:
# mv: cannot stat '/content/YoloV3/weights/last.pt': No such file or directory

# %%
! cd YoloV3
! mkdir Video
! cp -R "/content/gdrive/My Drive/data/0070-0350.mp4" "/content/YoloV3/Video"
# Out:
# /bin/bash: line 0: cd: YoloV3: No such file or directory

# %%
# !mkdir vidOutput
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/yolo_v3/vidOutput/" --source "/content/YoloV3/Video/0070-0350.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_v3/vidOutput/', save_txt=False, source='/content/YoloV3/Video/0070-0350.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# ...

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/yolo_v3/vidOutput/" --source "/content/gdrive/My Drive/data/Chocolate_wrapper_doll_making(360p).mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_v3/vidOutput/', save_txt=False, source='/content/gdrive/My Drive/data/Chocolate_wrapper_doll_making(360p).mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# batch=64
# subdivisions=16
# width=608
# height=608
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# ...
